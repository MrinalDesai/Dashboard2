# %%
import plotly.express as px 
import pandas as pd 
import numpy as np

# %%
df_per_main=pd.read_excel(f'datasets/SRTU/best worst 15-19.xlsx',sheet_name='Main')
df_per_grp=pd.read_excel(f'datasets/SRTU/best worst 15-19.xlsx',sheet_name='Group')

# %%
df_per_main.set_index('Year', inplace=True)

# %%
trans=df_per_main.T

# %%
trans.columns
# Out:
# Index(['2018-19', '2018-19', '2018-19', '2017-18', '2017-18', '2017-18',
#        '2015-16', '2015-16', '2015-16'],
#       dtype='object', name='Year')

# %%
trans
# Out:
# Year                                                                            2018-19  \
# Best Average Fleet Held (Numbers)                             Maharashtra SRTC (18,796)
# Best Average Age of Fleet (Years)                                  Ahmedabad MTC (3.98)
# Best Over-aged vehicles (%)                                               PUNBUS (0.00)
# Best Number of Accidents per Lakh Revenue Earni...                                  NaN
# Best Number of Fatal Accidents per Lakh Revenue...                                  NaN
# Best Revenue Earning Kilometres (Lakhs)                    Maharashtra SRTC (20,377.97)
# Best performing SRTUs - Staff Strength (Number)             Maharashtra SRTC (1,01,879)
# Best Fuel Efficiency (Km/litre of HSD) or Km/KG...      TN STC (Kumbakonam) Ltd. (5.73)
# Best  Passenger Kilometres Offered (Lakhs)               Maharashtra SRTC (8,82,977.00)
# Best Passenger Kms Performed (Lakhs)                     Maharashtra SRTC (6,10,514.00)
# ...
